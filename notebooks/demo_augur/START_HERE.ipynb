# %% [markdown]
# # Introduction to connecting and Querrying the Augur DB

# %% [markdown]
# If you made to this point, welcome! :) This short tutorial will show how to connect to the database and how to do a simple querry. If you need the config file please email cdolfi@redhat.com
#
# All the notebooks in this folder are based on https://github.com/chaoss/augur-community-reports templates.

# %% [markdown]
# ## Connect to your database

# %% [markdown]
# Until the Operate First enviroment can connect to the DB, use config file to access. Do not push config file to Github repo

# %%
import psycopg2
import pandas as pd 
import sqlalchemy as salc
import json
import os

with open("../../config.json") as config_file:
    config = json.load(config_file)

# %%
database_connection_string = 'postgresql+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = salc.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %% [markdown]
# ### Retrieve Available Respositories

# %%
repolist = pd.DataFrame()
repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT a.rg_name,
                a.repo_group_id,
                b.repo_name,
                b.repo_id,
                b.forked_from,
                b.repo_archived,
                b.repo_git
            FROM
                repo_groups a,
                repo b
            WHERE
                a.repo_group_id = b.repo_group_id
            ORDER BY
                rg_name,
                repo_name;
    """)
repolist = pd.read_sql(repo_query, con=engine)
display(repolist)
repolist.dtypes
# Out:
#                rg_name  repo_group_id repo_name  repo_id  \
# 0   Default Repo Group              1     augur        1
# 1             konveyor            101      NULL    25442
# 2             konveyor            101      NULL    25443
# 3             konveyor            101      NULL    25445
# 4             konveyor            101      NULL    25446
# ..                 ...            ...       ...      ...
# 66            konveyor            101      NULL    25497
# 67            konveyor            101      NULL    25498
# 68            konveyor            101      NULL    25486
# 69            konveyor            101      NULL    25441
# 70            konveyor            101      NULL    25499
#
#              forked_from  repo_archived  \
# 0   Parent not available              0
# 1   Parent not available              0
# 2   Parent not available              0
# 3   Parent not available              0
# 4   Parent not available              0
# ..                   ...            ...
# 66  Parent not available              0
# 67  Parent not available              0
# 68  Parent not available              0
# 69  Parent not available              0
# 70  Parent not available              0
#
#                                              repo_git
# 0                 https://github.com/chaoss/augur.git
# 1                https://github.com/konveyor/labs.git
# 2     https://github.com/konveyor/velero-examples.git
# 3     https://github.com/konveyor/move2kube-demos.git
# 4   https://github.com/konveyor/tackle-documentati...
# ..                                                ...
# 66  https://github.com/konveyor/tackle-commons-res...
# 67          https://github.com/konveyor/eng-kbase.git
# 68       https://github.com/konveyor/mtc-breakfix.git
# 69      https://github.com/konveyor/mig-demo-apps.git
# 70       https://github.com/konveyor/enhancements.git
#
# [71 rows x 7 columns]
# rg_name          object
# repo_group_id     int64
# repo_name        object
# repo_id           int64
# forked_from      object
# repo_archived     int64
# repo_git         object
# dtype: object

# %% [markdown]
# ### Create a Simpler List for quickly Identifying repo_group_id's and repo_id's for other queries

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT b.repo_id,
                a.repo_group_id,
                b.repo_name,
                a.rg_name,
                b.repo_git
            FROM
                repo_groups a,
                repo b 
            WHERE
                a.repo_group_id = b.repo_group_id 
            ORDER BY
                rg_name,
                repo_name;   

    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist[50:150]
# Out:
#     repo_id  repo_group_id repo_name   rg_name  \
# 50    25490            101      NULL  konveyor
# 51    25491            101      NULL  konveyor
# 52    25492            101      NULL  konveyor
# 53    25493            101      NULL  konveyor
# 54    25494            101      NULL  konveyor
# 55    25495            101      NULL  konveyor
# 56    25484            101      NULL  konveyor
# 57    25496            101      NULL  konveyor
# 58    25430            101      NULL  konveyor
# 59    25431            101      NULL  konveyor
# 60    25438            101      NULL  konveyor
# 61    25444            101      NULL  konveyor
# 62    25450            101      NULL  konveyor
# 63    25456            101      NULL  konveyor
# 64    25483            101      NULL  konveyor
# 65    25485            101      NULL  konveyor
# 66    25497            101      NULL  konveyor
# 67    25498            101      NULL  konveyor
# 68    25486            101      NULL  konveyor
# 69    25441            101      NULL  konveyor
# 70    25499            101      NULL  konveyor
#
#                                              repo_git
# 50     https://github.com/konveyor/crane-ui-tests.git
# 51             https://github.com/konveyor/mig-ci.git
# 52  https://github.com/konveyor/tackle-config-disc...
# 53        https://github.com/konveyor/must-gather.git
# 54         https://github.com/konveyor/data-mover.git
# 55       https://github.com/konveyor/virt-payload.git
# 56  https://github.com/konveyor/mig-analytics-tool...
# 57          https://github.com/konveyor/wadsworth.git
# 58          https://github.com/konveyor/move2kube.git
# 59            https://github.com/konveyor/pelorus.git
# 60  https://github.com/konveyor/forklift-controlle...
# 61  https://github.com/konveyor/move2kube-operator...
# 62          https://github.com/konveyor/tackle-ui.git
# 63  https://github.com/konveyor/tackle-application...
# 64              https://github.com/konveyor/crane.git
# 65     https://github.com/konveyor/rsync-transfer.git
# 66  https://github.com/konveyor/tackle-commons-res...
# 67          https://github.com/konveyor/eng-kbase.git
# 68       https://github.com/konveyor/mtc-breakfix.git
# 69      https://github.com/konveyor/mig-demo-apps.git
# 70       https://github.com/konveyor/enhancements.git

# %% [markdown]
# ### Create a list of all of the tables with the total number of data entries

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
                ANALYZE;
                SELECT schemaname,relname,n_live_tup 
                  FROM pg_stat_user_tables 
                  ORDER BY n_live_tup DESC;

    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist[:35]
# Out:
#           schemaname                          relname  n_live_tup
# 0         augur_data               pull_request_files      137311
# 1         augur_data                     issue_events       67098
# 2         augur_data              pull_request_events       51052
# 3         augur_data             pull_request_commits       41075
# 4         augur_data                          message       20023
# 5         augur_data                pull_request_meta       14943
# 6         augur_data             pull_request_reviews       11630
# 7         augur_data                           issues       10242
# 8         augur_data                issue_message_ref        9932
# 9         augur_data                    pull_requests        7507
# 10        augur_data  pull_request_review_message_ref        6399
# 11        augur_data                     contributors        5176
# 12        augur_data                     issue_labels        4988
# 13  augur_operations                   worker_history        2890
# 14        augur_data              pull_request_labels        2563
# 15        augur_data           pull_request_reviewers        2320
# 16        augur_data                  issue_assignees        1261
# 17        augur_data         pull_request_message_ref        1072
# 18        augur_data         contributor_affiliations         703
# 19        augur_data                        repo_info         673
# 20        augur_data           pull_request_assignees         491
# 21              spdx                         licenses         322
# 22        augur_data                    repo_insights         130
# 23        augur_data             chaoss_metric_status          80
# 24        augur_data                             repo          71
# 25            custom                      subprojects          70
# 26            custom                         repotemp          70
# 27        augur_data             merge_data_0_3014364          53
# 28            custom                         contribs          51
# 29        augur_data             merge_data_0_3708870          50
# 30        augur_data                merge_data_0_3610          49
# 31        augur_data                         releases          44
# 32        augur_data            repo_insights_records          43
# 33              spdx               relationship_types          30
# 34  augur_operations                       worker_job          21

# %% [markdown]
# Congrats you have done your first querries! There will be a few more simple examples below on how to pull an entire table. If you would like to explore on your own, the schema.png on the home sandiego directory will be greatly helpful in your explorations! Happy querrying :)

# %% [markdown]
# ### Data from the messages

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM message
    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist[:100]
# Out:
#      msg_id rgls_id                                           msg_text  \
# 0   1691707    None  Hello, I am an Outreachy applicant. I am inter...
# 1   1691708    None  Hi, I am Abhishek, currently pursuing B.Tech i...
# 2   1691709    None  Currently it seems that changes are required i...
# 3   1691710    None  @ccarterlandis I had a question regarding the ...
# 4   1691711    None  @sgoggins the first bug is just key not found ...
# ..      ...     ...                                                ...
# 95  1691798    None  Yes, I am using Ubuntu 19.10\n\nOn Fri, 13 Mar...
# 96  1691799    None  Oh I am so sorry, actually I replied directly ...
# 97  1691800    None  @sgoggins \r\nIs it like creating GitHub's Dep...
# 98  1691801    None  I started out using the local environment but ...
# 99  1691802    None            That works. I'll close this issue then.
#
#          msg_timestamp msg_sender_email msg_header  pltfrm_id  \
# 0  2020-03-06 12:16:26             None       None      25150
# 1  2020-03-14 08:24:40             None       None      25150
# 2  2020-06-07 19:32:47             None       None      25150
# 3  2020-03-22 16:14:31             None       None      25150
# 4  2021-01-05 15:48:50             None       None      25150
# ..                 ...              ...        ...        ...
# 95 2020-03-13 07:54:58             None       None      25150
# 96 2020-04-05 15:06:23             None       None      25150
# 97 2021-03-30 16:52:19             None       None      25150
# 98 2018-02-20 21:02:37             None       None      25150
# 99 2018-02-27 15:28:56             None       None      25150
#
#           tool_source tool_version data_source data_collection_date  cntrb_id
# 0   GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    278615
# 1   GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    278628
# 2   GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    277384
# 3   GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    277384
# 4   GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    277384
# ..                ...          ...         ...                  ...       ...
# 95  GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    277795
# 96  GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    277795
# 97  GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    278703
# 98  GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    278354
# 99  GitHub API Worker        1.0.0  GitHub API  2021-07-16 21:02:43    278354
#
# [100 rows x 12 columns]

# %% [markdown]
# ### Contributor affiliation data

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM contributor_affiliations
    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist[650:700]
# Out:
#      ca_id                                ca_domain ca_start_date  \
# 650  24277                          ross@heptio.com    1970-01-01
# 651  24278                      ross@kukulinski.com    1970-01-01
# 652  24279                         ralph@heptio.com    1970-01-01
# 653  24280               ralph.l.bankston@gmail.com    1970-01-01
# 654  24281                    alex_brand@heptio.com    1970-01-01
# 655  24282                    alexbrand09@gmail.com    1970-01-01
# 656  24283                           joe@heptio.com    1970-01-01
# 657  24284                joe.github@bedafamily.com    1970-01-01
# 658  24285                         vince@heptio.com    1970-01-01
# 659  24286                       vince@vincepri.com    1970-01-01
# 660  24287                         chuck@heptio.com    1970-01-01
# 661  24288                       ha.chuck@gmail.com    1970-01-01
# 662  24289                         jason@heptio.com    1970-01-01
# 663  24290                        detiber@gmail.com    1970-01-01
# 664  24291                    detiberusj@vmware.com    1970-01-01
# 665  24292                           liz@heptio.com    1970-01-01
# 666  24293        .*liztio@users.noreply.github.com    1970-01-01
# 667  24294                        naadir@heptio.com    1970-01-01
# 668  24295              naadir@randomvariable.co.uk    1970-01-01
# 669  24296  randomvariable@users.noreply.github.com    1970-01-01
# 670  24297                         ruben@heptio.com    1970-01-01
# 671  24298                        rubenoz@gmail.com    1970-01-01
# 672  24299                        rdodev@vmware.com    1970-01-01
# 673  25300                      tstclair@heptio.com    1970-01-01
# 674  25301       timothysc@users.noreply.github.com    1970-01-01
# 675  25302                    craigtracey@gmail.com    1970-01-01
# 676  25303                      luohui925@gmail.com    1970-01-01
# 677  25304                        davanum@gmail.com    1970-01-01
# 678  25305             amy@users.noreply.github.com    1970-01-01
# 679  25306                     bryanliles@gmail.com    1970-01-01
# 680  25307           bryan@Bryans-MacBook-Pro.local    1970-01-01
# 681  25308                        lilesb@vmware.com    1970-01-01
# 682  25309                        sfoohei@gmail.com    1970-01-01
# 683  25310                          foos@vmware.com    1970-01-01
# 684  25311                   mlandaverde@heptio.com    1970-01-01
# 685  25312        mdaverde@users.noreply.github.com    1970-01-01
# 686  25313                        shomron@gmail.com    1970-01-01
# 687  25314                         derek@heptio.com    1970-01-01
# 688  25315                   jderekwilson@gmail.com    1970-01-01
# 689  25316                          eric@heptio.com    1970-01-01
# 690  25317                    kate.kuchin@gmail.com    1970-01-01
# 691  25318                    suraci.alex@gmail.com    1970-01-01
# 692  25319                       asuraci@pivotal.io    1970-01-01
# 693  25320               alex@localhost.localdomain    1970-01-01
# 694  25321                  julian.zucker@gmail.com    1970-01-01
# 695  25322                   sahil.muthoo@gmail.com    1970-01-01
# 696  25323                          fali@pivotal.io    1970-01-01
# 697  25324                       fai28683@gmail.com    1970-01-01
# 698  25325                      dgarnier@pivotal.io    1970-01-01
# 699  25326                           git@garnier.wf    1970-01-01
#
#        tool_source tool_version                 data_source  \
# 650  Helper Script         None  Dawn's vmware_mapping JSON
# 651  Helper Script         None  Dawn's vmware_mapping JSON
# 652  Helper Script         None  Dawn's vmware_mapping JSON
# 653  Helper Script         None  Dawn's vmware_mapping JSON
# 654  Helper Script         None  Dawn's vmware_mapping JSON
# 655  Helper Script         None  Dawn's vmware_mapping JSON
# 656  Helper Script         None  Dawn's vmware_mapping JSON
# 657  Helper Script         None  Dawn's vmware_mapping JSON
# 658  Helper Script         None  Dawn's vmware_mapping JSON
# 659  Helper Script         None  Dawn's vmware_mapping JSON
# 660  Helper Script         None  Dawn's vmware_mapping JSON
# 661  Helper Script         None  Dawn's vmware_mapping JSON
# 662  Helper Script         None  Dawn's vmware_mapping JSON
# 663  Helper Script         None  Dawn's vmware_mapping JSON
# 664  Helper Script         None  Dawn's vmware_mapping JSON
# 665  Helper Script         None  Dawn's vmware_mapping JSON
# 666  Helper Script         None  Dawn's vmware_mapping JSON
# 667  Helper Script         None  Dawn's vmware_mapping JSON
# 668  Helper Script         None  Dawn's vmware_mapping JSON
# 669  Helper Script         None  Dawn's vmware_mapping JSON
# 670  Helper Script         None  Dawn's vmware_mapping JSON
# 671  Helper Script         None  Dawn's vmware_mapping JSON
# 672  Helper Script         None  Dawn's vmware_mapping JSON
# 673  Helper Script         None  Dawn's vmware_mapping JSON
# 674  Helper Script         None  Dawn's vmware_mapping JSON
# 675  Helper Script         None  Dawn's vmware_mapping JSON
# 676  Helper Script         None  Dawn's vmware_mapping JSON
# 677  Helper Script         None  Dawn's vmware_mapping JSON
# 678  Helper Script         None  Dawn's vmware_mapping JSON
# 679  Helper Script         None  Dawn's vmware_mapping JSON
# 680  Helper Script         None  Dawn's vmware_mapping JSON
# 681  Helper Script         None  Dawn's vmware_mapping JSON
# 682  Helper Script         None  Dawn's vmware_mapping JSON
# 683  Helper Script         None  Dawn's vmware_mapping JSON
# 684  Helper Script         None  Dawn's vmware_mapping JSON
# 685  Helper Script         None  Dawn's vmware_mapping JSON
# 686  Helper Script         None  Dawn's vmware_mapping JSON
# 687  Helper Script         None  Dawn's vmware_mapping JSON
# 688  Helper Script         None  Dawn's vmware_mapping JSON
# 689  Helper Script         None  Dawn's vmware_mapping JSON
# 690  Helper Script         None  Dawn's vmware_mapping JSON
# 691  Helper Script         None  Dawn's vmware_mapping JSON
# 692  Helper Script         None  Dawn's vmware_mapping JSON
# 693  Helper Script         None  Dawn's vmware_mapping JSON
# 694  Helper Script         None  Dawn's vmware_mapping JSON
# 695  Helper Script         None  Dawn's vmware_mapping JSON
# 696  Helper Script         None  Dawn's vmware_mapping JSON
# 697  Helper Script         None  Dawn's vmware_mapping JSON
# 698  Helper Script         None  Dawn's vmware_mapping JSON
# 699  Helper Script         None  Dawn's vmware_mapping JSON
#
#     data_collection_date        ca_last_used ca_affiliation  ca_active
# 650  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 651  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 652  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 653  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 654  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 655  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 656  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 657  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 658  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 659  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 660  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 661  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 662  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 663  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 664  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 665  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 666  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 667  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 668  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 669  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 670  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 671  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 672  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 673  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 674  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 675  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 676  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 677  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 678  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 679  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 680  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 681  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 682  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 683  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 684  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 685  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 686  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 687  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 688  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 689  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 690  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 691  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 692  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 693  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 694  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 695  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 696  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 697  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 698  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
# 699  2020-04-28 18:52:49 2020-04-28 18:52:49         VMware          1
