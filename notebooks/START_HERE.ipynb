# %% [markdown]
# # Introduction to connecting and Querying the Augur DB

# %% [markdown]
# If you made to this point, welcome! :) This short tutorial will show how to connect to the database and how to do a simple query. If you need the config file please email cdolfi@redhat.com
#
# For Project Sandiego's data, we will be using a personal instance of Augur. Augur is a software suite for collecting and measuring structured data about free and open-source software (FOSS) communities.
#
# Augur gather's trace data for a group of repositories, normalize it into the data model, and provide a variety of metrics about said data. The structure of the data model enables us to synthesize data across various platforms to provide meaningful context for meaningful questions about the way these communities evolve.
#
# All the notebooks in this folder are based on https://github.com/chaoss/augur-community-reports templates.

# %% [markdown]
# ## Connect to your database

# %% [markdown]
# Until the Operate First enviroment can connect to the DB, use config file to access. Do not push config file to Github repo

# %%
import psycopg2
import pandas as pd 
import sqlalchemy as salc
import json
import os

with open("../comm_cage.json") as config_file:
    config = json.load(config_file)

# %%
database_connection_string = 'postgresql+psycopg2://{}:{}@{}:{}/{}'.format(config['user'], config['password'], config['host'], config['port'], config['database'])

dbschema='augur_data'
engine = salc.create_engine(
    database_connection_string,
    connect_args={'options': '-csearch_path={}'.format(dbschema)})

# %% [markdown]
# ### Retrieve Available Respositories

# %%
aval_repos = pd.DataFrame()
repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT a.rg_name,
                a.repo_group_id,
                b.repo_name,
                b.repo_id,
                b.forked_from,
                b.repo_archived,
                b.repo_git
            FROM
                repo_groups a,
                repo b
            WHERE
                a.repo_group_id = b.repo_group_id
            ORDER BY
                rg_name,
                repo_name;
    """)
aval_repos = pd.read_sql(repo_query, con=engine)
display(aval_repos)
aval_repos.dtypes
# Out:
#                 rg_name  repo_group_id                   repo_name  repo_id  \
# 0    Default Repo Group             10                   blueprint    24442
# 1    Default Repo Group             10        grimoirelab-hatstall    25450
# 2    Default Repo Group             10  grimoirelab-perceval-opnfv    25445
# 3    Default Repo Group             10       operate-first-twitter    24441
# 4    Default Repo Group             10                 update-test    25430
# ..                  ...            ...                         ...      ...
# 116            torvalds          25648                       linux    36109
# 117            torvalds          25648                  pesconvert    36106
# 118            torvalds          25648         subsurface-for-dirk    36108
# 119            torvalds          25648                    test-tlb    36111
# 120            torvalds          25648                      uemacs    36107
#
#                forked_from  repo_archived  \
# 0     Parent not available            0.0
# 1     Parent not available            0.0
# 2     Parent not available            0.0
# 3     Parent not available            0.0
# 4     Parent not available            0.0
# ..                     ...            ...
# 116   Parent not available            0.0
# 117   Parent not available            0.0
# 118  subsurface/subsurface            0.0
# 119   Parent not available            0.0
# 120   Parent not available            0.0
#
#                                               repo_git
# 0           https://github.com/operate-first/blueprint
# 1       https://github.com/chaoss/grimoirelab-hatstall
# 2    https://github.com/chaoss/grimoirelab-perceval...
# 3    https://github.com/operate-first/operate-first...
# 4       https://github.com/SociallyCompute/update-test
# ..                                                 ...
# 116                  https://github.com/torvalds/linux
# 117             https://github.com/torvalds/pesconvert
# 118    https://github.com/torvalds/subsurface-for-dirk
# 119               https://github.com/torvalds/test-tlb
# 120                 https://github.com/torvalds/uemacs
#
# [121 rows x 7 columns]
# rg_name           object
# repo_group_id      int64
# repo_name         object
# repo_id            int64
# forked_from       object
# repo_archived    float64
# repo_git          object
# dtype: object

# %% [markdown]
# ### Create a Simpler List for quickly Identifying repo_group_id's and repo_id's for other queries

# %%
repolist = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT b.repo_id,
                a.repo_group_id,
                b.repo_name,
                a.rg_name,
                b.repo_git
            FROM
                repo_groups a,
                repo b 
            WHERE
                a.repo_group_id = b.repo_group_id 
            ORDER BY
                rg_name,
                repo_name;   

    """)

repolist = pd.read_sql(repo_query, con=engine)

repolist
# Out:
#      repo_id  repo_group_id                   repo_name             rg_name  \
# 0      24442             10                   blueprint  Default Repo Group
# 1      25450             10        grimoirelab-hatstall  Default Repo Group
# 2      25445             10  grimoirelab-perceval-opnfv  Default Repo Group
# 3      24441             10       operate-first-twitter  Default Repo Group
# 4      25430             10                 update-test  Default Repo Group
# ..       ...            ...                         ...                 ...
# 116    36109          25648                       linux            torvalds
# 117    36106          25648                  pesconvert            torvalds
# 118    36108          25648         subsurface-for-dirk            torvalds
# 119    36111          25648                    test-tlb            torvalds
# 120    36107          25648                      uemacs            torvalds
#
#                                               repo_git
# 0           https://github.com/operate-first/blueprint
# 1       https://github.com/chaoss/grimoirelab-hatstall
# 2    https://github.com/chaoss/grimoirelab-perceval...
# 3    https://github.com/operate-first/operate-first...
# 4       https://github.com/SociallyCompute/update-test
# ..                                                 ...
# 116                  https://github.com/torvalds/linux
# 117             https://github.com/torvalds/pesconvert
# 118    https://github.com/torvalds/subsurface-for-dirk
# 119               https://github.com/torvalds/test-tlb
# 120                 https://github.com/torvalds/uemacs
#
# [121 rows x 5 columns]

# %%
repolist[50:70]
# Out:
#     repo_id  repo_group_id                    repo_name   rg_name  \
# 50    30740          25481                    move2kube  konveyor
# 51    30770          25481                move2kube-api  konveyor
# 52    30789          25481              move2kube-demos  konveyor
# 53    30729          25481           move2kube-katacoda  konveyor
# 54    30720          25481           move2kube-operator  konveyor
# 55    30718          25481              move2kube-tests  konveyor
# 56    30745          25481                 move2kube-ui  konveyor
# 57    30783          25481                 mtc-breakfix  konveyor
# 58    30788          25481                  must-gather  konveyor
# 59    30779          25481                oadp-capstone  konveyor
# 60    30749          25481           oadp-documentation  konveyor
# 61    30778          25481   openshift-migration-plugin  konveyor
# 62    30736          25481                      openvpn  konveyor
# 63    30757          25481                      pelorus  konveyor
# 64    30790          25481                        pprof  konveyor
# 65    30777          25481                  pvc-migrate  konveyor
# 66    30719          25481               rsync-transfer  konveyor
# 67    30756          25481                        stern  konveyor
# 68    30751          25481                       tackle  konveyor
# 69    30722          25481  tackle-application-importer  konveyor
#
#                                              repo_git
# 50              https://github.com/konveyor/move2kube
# 51          https://github.com/konveyor/move2kube-api
# 52        https://github.com/konveyor/move2kube-demos
# 53     https://github.com/konveyor/move2kube-katacoda
# 54     https://github.com/konveyor/move2kube-operator
# 55        https://github.com/konveyor/move2kube-tests
# 56           https://github.com/konveyor/move2kube-ui
# 57           https://github.com/konveyor/mtc-breakfix
# 58            https://github.com/konveyor/must-gather
# 59          https://github.com/konveyor/oadp-capstone
# 60     https://github.com/konveyor/oadp-documentation
# 61  https://github.com/konveyor/openshift-migratio...
# 62                https://github.com/konveyor/openvpn
# 63                https://github.com/konveyor/pelorus
# 64                  https://github.com/konveyor/pprof
# 65            https://github.com/konveyor/pvc-migrate
# 66         https://github.com/konveyor/rsync-transfer
# 67                  https://github.com/konveyor/stern
# 68                 https://github.com/konveyor/tackle
# 69  https://github.com/konveyor/tackle-application...

# %% [markdown]
# ### Create a list of all of the tables with the total number of data entries

# %%
data_entries = pd.DataFrame()

repo_query = salc.sql.text(f"""
                ANALYZE;
                SELECT schemaname,relname,n_live_tup 
                  FROM pg_stat_user_tables 
                  ORDER BY n_live_tup DESC;

    """)

data_entries = pd.read_sql(repo_query, con=engine)

data_entries
# Out:
#            schemaname               relname  n_live_tup
# 0          augur_data               commits     2776170
# 1          augur_data      contributor_repo      292334
# 2          augur_data        dm_repo_weekly      274448
# 3          augur_data  dm_repo_group_weekly      273697
# 4          augur_data       dm_repo_monthly      176061
# ..                ...                   ...         ...
# 100              spdx                 files           0
# 101  augur_operations       repos_fetch_log           0
# 102        augur_data     pull_request_repo           0
# 103              spdx        files_licenses           0
# 104        augur_data             repo_meta           0
#
# [105 rows x 3 columns]

# %% [markdown]
# Congrats you have done your first queries! There will be a few more simple examples below on how to pull an entire table. If you would like to explore on your own, the schema.png on the home sandiego directory will be greatly helpful in your explorations! Happy querying :)

# %% [markdown]
# ### Data from the messages
#
# This data is the collection of all comments from any issue, PR, commit, etc opened. This example shows another side of the database and the types of data we can pull from it.

# %%
mes_data = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM message
    """)

mes_data = pd.read_sql(repo_query, con=engine)

mes_data
# Out:
#        msg_id rgls_id  platform_msg_id                      platform_node_id  \
# 0       25430    None        826722981  MDEyOklzc3VlQ29tbWVudDgyNjcyMjk4MQ==
# 1       25431    None        826812453  MDEyOklzc3VlQ29tbWVudDgyNjgxMjQ1Mw==
# 2       25432    None        826815197  MDEyOklzc3VlQ29tbWVudDgyNjgxNTE5Nw==
# 3       25433    None        826817026  MDEyOklzc3VlQ29tbWVudDgyNjgxNzAyNg==
# 4       25434    None        826822231  MDEyOklzc3VlQ29tbWVudDgyNjgyMjIzMQ==
# ...       ...     ...              ...                                   ...
# 39835   69684    None        882431101                   IC_kwDOEMblf840mNR9
# 39836   69685    None        882431342                   IC_kwDOEMblf840mNVu
# 39837   69686    None        846151549  MDEyOklzc3VlQ29tbWVudDg0NjE1MTU0OQ==
# 39838   69687    None        847149399  MDEyOklzc3VlQ29tbWVudDg0NzE0OTM5OQ==
# 39839   69688    None        960311996                   IC_kwDOFaIjPc45PTK8
#
#        repo_id  cntrb_id                                           msg_text  \
# 0          NaN     25440  I've enabled actions for this repo. LMK if it ...
# 1          NaN     25449  [APPROVALNOTIFIER] This PR is **NOT APPROVED**...
# 2          NaN     25438         Actions seems to be working now. Thanks 👍
# 3          NaN     25440                                   /cc @oindrillac
# 4          NaN     25449  [APPROVALNOTIFIER] This PR is **NOT APPROVED**...
# ...        ...       ...                                                ...
# 39835      NaN     57762  Thank you for the reminder, we forgot to add.\...
# 39836      NaN     57762  Closes https://github.com/konveyor/imagestream...
# 39837      NaN     57772           Closing as preview is confirmed working!
# 39838      NaN     57772                 currently working this in a branch
# 39839      NaN     57762         This is pretty cool, thanks for capturing
#
#             msg_timestamp msg_sender_email msg_header  pltfrm_id  \
# 0     2021-04-26 10:35:38             None       None      25150
# 1     2021-04-26 12:55:35             None       None      25150
# 2     2021-04-26 12:59:50             None       None      25150
# 3     2021-04-26 13:02:13             None       None      25150
# 4     2021-04-26 13:09:08             None       None      25150
# ...                   ...              ...        ...        ...
# 39835 2021-07-19 10:20:22             None       None      25150
# 39836 2021-07-19 10:20:42             None       None      25150
# 39837 2021-05-21 18:25:47             None       None      25150
# 39838 2021-05-24 16:04:03             None       None      25150
# 39839 2021-11-04 00:15:11             None       None      25150
#
#              tool_source tool_version data_source data_collection_date
# 0      GitHub API Worker        1.0.0  GitHub API  2021-10-21 13:41:55
# 1      GitHub API Worker        1.0.0  GitHub API  2021-10-21 13:41:55
# 2      GitHub API Worker        1.0.0  GitHub API  2021-10-21 13:41:55
# 3      GitHub API Worker        1.0.0  GitHub API  2021-10-21 13:41:55
# 4      GitHub API Worker        1.0.0  GitHub API  2021-10-21 13:41:55
# ...                  ...          ...         ...                  ...
# 39835  GitHub API Worker        1.0.0  GitHub API  2021-11-03 22:25:47
# 39836  GitHub API Worker        1.0.0  GitHub API  2021-11-03 22:25:47
# 39837  GitHub API Worker        1.0.0  GitHub API  2021-11-03 22:25:52
# 39838  GitHub API Worker        1.0.0  GitHub API  2021-11-03 22:25:52
# 39839  GitHub API Worker        1.0.0  GitHub API  2021-11-03 22:25:52
#
# [39840 rows x 15 columns]

# %% [markdown]
# ### Contributor affiliation data
#
#
# This data tells us what is the company affiliation of many open source contributors. This can help tell us which companies are involved in a certian open source project.

# %%
con_aff = pd.DataFrame()

repo_query = salc.sql.text(f"""
             SET SCHEMA 'augur_data';
             SELECT * FROM contributor_affiliations
    """)

con_aff = pd.read_sql(repo_query, con=engine)

con_aff
# Out:
#      ca_id            ca_domain ca_start_date        ca_last_used  \
# 0        1          samsung.com    1970-01-01 2018-08-01 18:37:54
# 1        2  linuxfoundation.org    1970-01-01 2018-08-01 18:37:54
# 2        3              ibm.com    1970-01-01 2018-08-01 18:37:54
# 3        8          walmart.com    1970-01-01 2018-09-01 06:00:00
# 4        9       exxonmobil.com    1970-01-01 2018-09-01 06:00:00
# ..     ...                  ...           ...                 ...
# 515    516          twitter.com    1970-01-01 2018-09-01 06:00:00
# 516    517            adobe.com    1970-01-01 2018-09-01 06:00:00
# 517    519              acm.org    1970-01-01 2018-09-12 02:01:59
# 518    520     outdoors@acm.org    1970-01-01 2018-09-12 02:32:53
# 519    521          freebsd.org    1970-01-01 2018-09-13 21:15:22
#
#              ca_affiliation  ca_active tool_source tool_version data_source  \
# 0                   Samsung          1        load          1.0        load
# 1          Linux Foundation          1        load          1.0        load
# 2                       IBM          1        load          1.0        load
# 3                   Walmart          1        load          1.0        load
# 4               Exxon Mobil          1        load          1.0        load
# ..                      ...        ...         ...          ...         ...
# 515                 Twitter          1        load          1.0        load
# 516                   Adobe          1        load          1.0        load
# 517                     ACM          1        load          1.0        load
# 518  University of Missouri          1        load          1.0        load
# 519                Free BSD          1        load          1.0        load
#
#     data_collection_date
# 0             1970-01-01
# 1             1970-01-01
# 2             1970-01-01
# 3             1970-01-01
# 4             1970-01-01
# ..                   ...
# 515           1970-01-01
# 516           1970-01-01
# 517           1970-01-01
# 518           2013-07-15
# 519           1970-01-01
#
# [520 rows x 10 columns]
